# %% [markdown]
# __1.__ Найти производную $y'_{x}$ функции:
#
# ### $$\mbox{arctg}(\frac{y}{x})=\ln \sqrt{x^2+y^2}$$
# ### $$\frac{(\frac{y}{x})'}{1+(\frac{y}{x})^2}=\frac{(\sqrt{x^2+y^2})'}{\sqrt{x^2+y^2}}$$
# ### $$\frac{\frac{y'x-y}{x^2}}{1+(\frac{y}{x})^2}=\frac{\frac{(x^2+y^2)'}{2\sqrt{x^2+y^2}}}{\sqrt{x^2+y^2}}$$
# ### $$\frac{y'x-y}{x^2+y^2}=\frac{(x^2+y^2)'}{2\cdot(x^2+y^2)}$$
# ### $$\frac{y'x-y}{x^2+y^2}=\frac{2x+2yy'}{2\cdot(x^2+y^2)}$$
# ### $$y'x-y=x+yy'$$
# ### $$y'x-yy'=x+y$$
# ### $$y'(x-y)=y+x$$
# ### $$y'=\frac{x+y}{x-y}$$

# %% [markdown]
# __2.__ Найти производную $y'_{x}$ функции:
#
# ### \begin{cases}
#    y=\frac{t^2}{t-1}, \\
#    x=\frac{t}{t^2-1}
#  \end{cases}
#
# ###  $$y'_{x}=\frac{y'_{t}}{x'_{t}}=\frac{(\frac{t^2}{t-1})'}{(\frac{t}{t^2-1} )'}=
# \frac{\frac{2t(t-1)-t^2}{(t-1)^2}}{\frac{t^2-1-2t^2}{(t^2-1)^2}}=
# -\frac{(t^2-2t)(t^2-1)^2}{(t^2+1)(t-1)^2}
#  $$

# %% [markdown]
# __3.__ Найти производную с помощью логарифмирования:
#
# ### $$y=(x^2+2)^5\cdot(3x-x^3)^3$$
#
# ### $$y'=(x^2+2)^5\cdot(3x-x^3)^3\cdot(\ln((x^2+2)^5\cdot(3x-x^3)^3))'=
# (x^2+2)^5\cdot(3x-x^3)^3\cdot
# (\frac{5(x^2+2)'}{(x^2+2)}+\frac{3(3x-x^3)'}{(3x-x^3)})=
# (x^2+2)^5\cdot(3x-x^3)^3\cdot
# (\frac{10x}{(x^2+2)}+\frac{9-9x^2}{(3x-x^3)})=
# \frac{(x^2+2)^5\cdot(3x-x^3)^3\cdot10x}{(x^2+2)}+\frac{(x^2+2)^5\cdot(3x-x^3)^3\cdot(9-9x^2)}{(3x-x^3)}=
# (x^2+2)^4\cdot(3x-x^3)^3\cdot10x+(x^2+2)^5\cdot(3x-x^3)^2\cdot(9-9x^2)
# $$

# %% [markdown]
# __4.__ Найти производную функции с помощью логарифмирования:
#
# ### $$y=x^x$$
#
# ### $$y'=x^x\cdot(\ln(x^x))'
# =x^x\cdot(x\cdot\ln(x))'=
# x^x\cdot(1\cdot\ln(x)+x\cdot\frac{1}{x})=
# x^x\cdot(\ln(x)+1)$$

# %% [markdown]
# __5.__ Найти производную функции с помощью логарифмирования:
#
# ### $$y=\frac{(2-x^2)^3\cdot(x-1)^2}{(2x^3-3x)\cdot e^x}$$
#
# ### $$y'=\frac{(2-x^2)^3\cdot(x-1)^2}{(2x^3-3x)\cdot e^x}\cdot(\ln(\frac{(2-x^2)^3\cdot(x-1)^2}{(2x^3-3x)\cdot e^x}))'=
# \frac{(2-x^2)^3\cdot(x-1)^2}{(2x^3-3x)\cdot e^x}\cdot(\frac{3(2-x^2)'}{2-x^2}+\frac{2(x-1)'}{x-1}-\frac{(2x^3-3x)'}{2x^3-3x}-1)=
# \frac{(2-x^2)^3\cdot(x-1)^2}{(2x^3-3x)\cdot e^x}\cdot(\frac{-6x}{2-x^2}+\frac{2}{x-1}-\frac{6x^2-3}{2x^3-3x}-1)$$

# %% [markdown]
# __7.__ Найти длину $𝑥$ и ширину $𝑦$ прямоугольника при заданном периметре $𝑃=144$ cм, при которых данный прямоугольник имеет наибольшую площадь $𝑆$.
#
# ### $$P=2x+2y$$
# ### $$S=xy=x\cdot(\frac{P-2x}{2})=-x^2+\frac{P}{2}x \rightarrow \max$$
# ### $$S'=-2x+\frac{P}{2}=0$$
# ### $$x=\frac{P}{4}$$
# ![img-2021-08-29-16-28-54.png](data:image/png;base64,...)
# ### $S$ имеет максимальное значение при $x=\frac{P}{4}=\frac{144}{4}=36$ и $y=\frac{P}{2}-x=\frac{144}{2}-36=36$

# %% [markdown]
# __8*.__ Завод $A$ отстоит от железной дороги, идущей с юга на север и проходящей через $B$, считая по кратчайшему расстоянию на $a$ км. Под каким углом $\alpha$ к железной дороге следует ппостроить подъезной  путь от завода, чтобы транспортировка грузов из $A$ в $B$ была наиболее экономичной, если стоимость провоза тонны груза на расстоянии $1$ км составляет: по подъезному пути $p$ рублей, по железной дороге $q$ рублей $(p>q)$ и город $B$ расположен на $b$ км севернее завода $A$.
# ### ![Без названия.png](data:image/png;base64,...)

# %%
import numpy as np
from sympy import *
init_printing()

x=Symbol('x')

y=(((2-x**2)**3)*(x-1)**2)/((2*x**3-3*x)*np.e**x)

diff(y,x)
# Out:
#                                  2                                       3
#                     -x   ⎛     2⎞         2                   -x ⎛     2⎞  ⎛
#   6⋅2.71828182845905  ⋅x⋅⎝2 - x ⎠ ⋅(x - 1)    2.71828182845905  ⋅⎝2 - x ⎠ ⋅⎝3
# - ───────────────────────────────────────── + ────────────────────────────────
#                      3                                                     2
#                   2⋅x  - 3⋅x                                   ⎛   3      ⎞
#                                                                ⎝2⋅x  - 3⋅x⎠
#
#                                               3
#      2⎞        2                   -x ⎛     2⎞         2                   -x
# - 6⋅x ⎠⋅(x - 1)    2.71828182845905  ⋅⎝2 - x ⎠ ⋅(x - 1)    2.71828182845905  ⋅
# ──────────────── - ───────────────────────────────────── + ───────────────────
#                                     3                                       3
# ...

# %%
(2/(x-1))*y
# Out:
#                              3
#                   -x ⎛     2⎞
# 2⋅2.71828182845905  ⋅⎝2 - x ⎠ ⋅(x - 1)
# ──────────────────────────────────────
#                  3
#               2⋅x  - 3⋅x
